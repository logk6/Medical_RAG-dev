# %%
import json
import os
import re
from elasticsearch import Elasticsearch, helpers
from pathlib import Path
from tqdm import tqdm

password = "7n2xK2kELC0GYsOCyi9+"
# ca_sert=r"C:\Users\Dung\Downloads\elasticsearch-9.2.0-windows-x86_64\elasticsearch-9.2.0\config\certs\http_ca.crt"
es = Elasticsearch(
            ['https://localhost:9200'],
            basic_auth=('elastic', password),
            verify_certs=False,
            # ca_certs=ca_sert,
            request_timeout=60
        )

es.info()
# Out:
# D:\DUNG\MasterProgram\Project_I\Medical_RAG_Project\.venv\Lib\site-packages\elasticsearch\_sync\client\__init__.py:313: SecurityWarning: Connecting to 'https://localhost:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(
# D:\DUNG\MasterProgram\Project_I\Medical_RAG_Project\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ObjectApiResponse({'name': 'LAP-CN-202', 'cluster_name': 'elasticsearch', 'cluster_uuid': 'dZuZa2UEQhKesVFtLNUaBg', 'version': {'number': '9.2.0', 'build_flavor': 'default', 'build_type': 'zip', 'build_hash': '25d88452371273dd27356c98598287b669a03eae', 'build_date': '2025-10-21T10:06:21.288851013Z', 'build_snapshot': False, 'lucene_version': '10.3.1', 'minimum_wire_compatibility_version': '8.19.0', 'minimum_index_compatibility_version': '8.0.0'}, 'tagline': 'You Know, for Search'})

# %%
# query = {'_source': ['id', 'title', 'text_chunked'], 'query': {'terms': {'id': ['doc_0_chunk_4', 'doc_0_chunk_8', 'doc_0_chunk_47', 'doc_0_chunk_49', 'doc_0_chunk_40']}}, 'size': 5}
# res = es.search(index=index_name, body=query)
# for hit in res["hits"]["hits"]:
#     print(hit["_source"])

# Count and print the number of documents in the index
es.indices.delete(index="test_index")
count_result = es.count(index="test_index")
# count_result = es.count(index="pubmed_index_embedded")
print(f"Index contains {count_result['count']} documents.")
# Out:
# D:\DUNG\MasterProgram\Project_I\Medical_RAG_Project\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# D:\DUNG\MasterProgram\Project_I\Medical_RAG_Project\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[7], line 8
#       1 # query = {'_source': ['id', 'title', 'text_chunked'], 'query': {'terms': {'id': ['doc_0_chunk_4', 'doc_0_chunk_8', 'doc_0_chunk_47', 'doc_0_chunk_49', 'doc_0_chunk_40']}}, 'size': 5}
#       2 # res = es.search(index=index_name, body=query)
#       3 # for hit in res["hits"]["hits"]:
#       4 #     print(hit["_source"])
#       5
#       6 # Count and print the number of documents in the index
#       7 es.indices.delete(index="test_index")
# ----> 8 count_result = es.count(index="test_index")
#       9 # count_result = es.count(index="pubmed_index_embedded")
#      10 print(f"Index contains {count_result['count']} documents.")
#
# File D:\DUNG\MasterProgram\Project_I\Medical_RAG_Project\.venv\Lib\site-packages\elasticsearch\_sync\client\utils.py:415, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     412         except KeyError:
#     413             pass
# --> 415 return api(*args, **kwargs)
#
# File D:\DUNG\MasterProgram\Project_I\Medical_RAG_Project\.venv\Lib\site-packages\elasticsearch\_sync\client\__init__.py:1017, in Elasticsearch.count(self, index, allow_no_indices, analyze_wildcard, analyzer, default_operator, df, error_trace, expand_wildcards, filter_path, human, ignore_throttled, ignore_unavailable, lenient, min_score, preference, pretty, project_routing, q, query, routing, terminate_after, body)
#    1015 if __body is not None:
#    1016     __headers["content-type"] = "application/json"
# -> 1017 return self.perform_request(  # type: ignore[return-value]
#    1018     "POST",
#    1019     __path,
#    1020     params=__query,
#    1021     headers=__headers,
#    1022     body=__body,
#    1023     endpoint_id="count",
#    1024     path_parts=__path_parts,
#    1025 )
#
# File D:\DUNG\MasterProgram\Project_I\Medical_RAG_Project\.venv\Lib\site-packages\elasticsearch\_sync\client\_base.py:271, in BaseClient.perform_request(self, method, path, params, headers, body, endpoint_id, path_parts)
#     255 def perform_request(
#     256     self,
#     257     method: str,
#    (...)    264     path_parts: Optional[Mapping[str, Any]] = None,
#     265 ) -> ApiResponse[Any]:
#     266     with self._otel.span(
#     267         method,
#     268         endpoint_id=endpoint_id,
#     269         path_parts=path_parts or {},
#     270     ) as otel_span:
# --> 271         response = self._perform_request(
#     272             method,
#     273             path,
#     274             params=params,
#     275             headers=headers,
#     276             body=body,
#     277             otel_span=otel_span,
#     278         )
#     279         otel_span.set_elastic_cloud_metadata(response.meta.headers)
#     280         return response
#
# File D:\DUNG\MasterProgram\Project_I\Medical_RAG_Project\.venv\Lib\site-packages\elasticsearch\_sync\client\_base.py:351, in BaseClient._perform_request(self, method, path, params, headers, body, otel_span)
#     348         except (ValueError, KeyError, TypeError):
#     349             pass
# --> 351     raise HTTP_EXCEPTIONS.get(meta.status, ApiError)(
#     352         message=message, meta=meta, body=resp_body
#     353     )
#     355 # 'X-Elastic-Product: Elasticsearch' should be on every 2XX response.
#     356 if not self._verified_elasticsearch:
#     357     # If the header is set we mark the server as verified.
#
# NotFoundError: NotFoundError(404, 'index_not_found_exception', 'no such index [test_index]', test_index, index_or_alias)
